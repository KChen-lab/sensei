# %% [markdown]
# # Introduction
#
# Three groups: microsatellite instability high (MSI-H), microsatellite instability low (MSI-L) and microsatellite stable (MSS).
#
# Two sets of measurements: 7_marker, 5_marker. The original report consider one sample as MSI if both indicate positive.

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# mpl.rcParams['figure.dpi'] = 600

# %%
df = pd.read_excel("41591_2016_BFnm4191_MOESM27_ESM.xlsx", index=1)
df
# Out:
#        Sample Name  \
# 0     TCGA-GV-A6ZA
# 1     TCGA-H4-A2HO
# 2     TCGA-H4-A2HQ
# 3     TCGA-HQ-A2OE
# 4     TCGA-HQ-A2OF
# ...            ...
# 5925  TCGA-QS-A8F1
# 5926  TCGA-SJ-A6ZI
# 5927  TCGA-SJ-A6ZJ
# 5928  TCGA-SL-A6J9
# 5929  TCGA-SL-A6JA
#
#       Average difference in microsatellite alleles relative to paired normal  \
# 0                                             -0.000393
# 1                                              0.001674
# 2                                              0.000091
# 3                                              0.000061
# 4                                              0.000605
# ...                                                 ...
# 5925                                          -0.000477
# 5926                                           0.008849
# 5927                                           0.002213
# 5928                                          -0.000376
# 5929                                           0.010516
#
#       Number Unstable Loci  Number Loci Called  Proportion Unstable Loci  \
# 0                      510              144859                  0.003521
# 1                     1203              244912                  0.004912
# 2                      915              230733                  0.003966
# 3                      526              165003                  0.003188
# 4                      407              128967                  0.003156
# ...                    ...                 ...                       ...
# 5925                  1316              226304                  0.005815
# 5926                  3363              298901                  0.011251
# 5927                  1610              239070                  0.006734
# 5928                  1023              194265                  0.005266
# 5929                  2326              196834                  0.011817
#
#      Stability at chr8:7679723-7679741  MOSAIC classification Tumor Type  \
# 0                                stable                   MSS       BLCA
# 1                                stable                   MSS       BLCA
# 2                                stable                   MSS       BLCA
# 3                                stable                   MSS       BLCA
# 4                                stable                   MSS       BLCA
# ...                                 ...                   ...        ...
# 5925                             stable                   MSS       UCEC
# 5926                           unstable                 MSI-H       UCEC
# 5927                             stable                   MSS       UCEC
# 5928                             stable                   MSS       UCEC
# 5929                           unstable                 MSI-H       UCEC
#
#      MSI-PCR Result In Training Set?
# 0               NaN               no
# 1               NaN               no
# 2               NaN               no
# 3               NaN               no
# 4               NaN               no
# ...             ...              ...
# 5925             ND               no
# 5926             ND               no
# 5927             ND               no
# 5928             ND               no
# 5929             ND               no
#
# [5930 rows x 10 columns]

# %%
df[df['Tumor Type'] == 'UCEC']['MOSAIC classification'].value_counts().plot(kind="bar")

# %%
f = lambda x: x[0:3]
msi_mask = (df['MOSAIC classification'] == 'MSI-H') & (df['Tumor Type'] == 'UCEC')
mss_mask = (df['MOSAIC classification'] == 'MSS') & (df['Tumor Type'] == 'UCEC')

msi_patient_id = df['Sample Name'][msi_mask].to_frame()
mss_patient_id = df['Sample Name'][mss_mask].to_frame()

msi_patient_id['microsatellite'] = 'MSI-H'
mss_patient_id['microsatellite'] = 'MSS'

microsatellite_label_df = msi_patient_id.append(mss_patient_id)

# %%
data = pd.read_csv("TCGA.Kallisto.fullIDs.cibersort.relative.tsv", sep="\t")
data["SampleID"] = data["SampleID"].apply(lambda x: x.replace('.', '-'))
data["PatientID"] = data["SampleID"].apply(lambda x: '-'.join(x.split('-')[0:3]))

# %%
merged = data.merge(microsatellite_label_df, left_on="PatientID", right_on='Sample Name')

# %%
merged.microsatellite.value_counts().plot(kind="bar")

# %%
cell_types = ['B.cells.naive', 'B.cells.memory', 'Plasma.cells', 'T.cells.CD8',
       'T.cells.CD4.naive', 'T.cells.CD4.memory.resting',
       'T.cells.CD4.memory.activated', 'T.cells.follicular.helper',
       'T.cells.regulatory..Tregs.', 'T.cells.gamma.delta', 'NK.cells.resting',
       'NK.cells.activated', 'Monocytes', 'Macrophages.M0', 'Macrophages.M1',
       'Macrophages.M2', 'Dendritic.cells.resting',
       'Dendritic.cells.activated', 'Mast.cells.resting',
       'Mast.cells.activated', 'Eosinophils', 'Neutrophils']

#merged['Leukocytes.all'] = merged[cell_types].sum(1)

merged['T.cells.all'] = merged[['T.cells.CD8',
                                    'T.cells.CD4.naive',
                                    'T.cells.CD4.memory.resting',
                                    'T.cells.CD4.memory.activated',
                                    'T.cells.follicular.helper',
                                    'T.cells.regulatory..Tregs.',
                                    'T.cells.gamma.delta']].sum(1)

merged['B.cells.all'] = merged[['B.cells.naive', 'B.cells.memory']].sum(1)

merged['Nk.cells.all'] = merged[['NK.cells.resting', 'NK.cells.activated']].sum(1)

merged['Macrophages.all'] = merged[['Macrophages.M0', 'Macrophages.M1', 'Macrophages.M2']].sum(1)

merged['Dendritic.cells.all'] = merged[['Dendritic.cells.resting', 'Dendritic.cells.activated']].sum(1)

merged['Mast.cells.all'] = merged[['Mast.cells.resting', 'Mast.cells.activated']].sum(1)



augmented_cell_types = cell_types + ['T.cells.all', 'B.cells.all', 'Nk.cells.all', 'Macrophages.all', 
                                     'Dendritic.cells.all', 'Mast.cells.all']

merged
# Out:
#                          SampleID CancerType  B.cells.naive  B.cells.memory  \
# 0    TCGA-EO-A22Y-01A-11R-A180-07       UCEC       0.000000        0.080634
# 1    TCGA-BK-A56F-01A-32R-A27V-07       UCEC       0.000000        0.053266
# 2    TCGA-PG-A5BC-01A-12R-A27V-07       UCEC       0.106488        0.019595
# 3    TCGA-EY-A54A-01A-11R-A27V-07       UCEC       0.017354        0.000000
# 4    TCGA-AJ-A3NC-01A-11R-A22K-07       UCEC       0.067656        0.012511
# ..                            ...        ...            ...             ...
# 459  TCGA-4E-A92E-01A-11R-A37O-07       UCEC       0.046195        0.000000
# 460  TCGA-2E-A9G8-01A-11R-A40A-07       UCEC       0.000000        0.035739
# 461  TCGA-A5-AB3J-01A-11R-A40A-07       UCEC       0.229559        0.000000
# 462  TCGA-JU-AAVI-01A-11R-A40A-07       UCEC       0.021791        0.000000
# 463  TCGA-DI-A1BU-01A-11R-A137-07       UCEC       0.020649        0.000000
#
#      Plasma.cells  T.cells.CD8  T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 0        0.008700     0.066424                0.0                    0.120280
# 1        0.056248     0.114693                0.0                    0.189724
# 2        0.076636     0.122491                0.0                    0.203831
# 3        0.038209     0.042937                0.0                    0.307244
# 4        0.028619     0.053432                0.0                    0.137966
# ..            ...          ...                ...                         ...
# 459      0.030850     0.205641                0.0                    0.063863
# 460      0.111000     0.168203                0.0                    0.000000
# 461      0.143764     0.065165                0.0                    0.178858
# 462      0.054091     0.312219                0.0                    0.000000
# 463      0.031851     0.197062                0.0                    0.088836
#
#      T.cells.CD4.memory.activated  T.cells.follicular.helper  ...      RMSE  \
# 0                             0.0                   0.064272  ...  1.092848
# 1                             0.0                   0.052596  ...  1.012650
# 2                             0.0                   0.100763  ...  0.994089
# 3                             0.0                   0.079982  ...  1.052465
# 4                             0.0                   0.098371  ...  1.047294
# ..                            ...                        ...  ...       ...
# 459                           0.0                   0.178285  ...  1.034397
# 460                           0.0                   0.197915  ...  1.002022
# 461                           0.0                   0.055698  ...  0.915280
# 462                           0.0                   0.260242  ...  1.089860
# 463                           0.0                   0.238823  ...  1.068255
#
#         PatientID   Sample Name  microsatellite  T.cells.all  B.cells.all  \
# 0    TCGA-EO-A22Y  TCGA-EO-A22Y             MSS     0.278390     0.080634
# 1    TCGA-BK-A56F  TCGA-BK-A56F             MSS     0.408309     0.053266
# 2    TCGA-PG-A5BC  TCGA-PG-A5BC             MSS     0.435877     0.126083
# 3    TCGA-EY-A54A  TCGA-EY-A54A             MSS     0.430163     0.017354
# 4    TCGA-AJ-A3NC  TCGA-AJ-A3NC             MSS     0.354307     0.080167
# ..            ...           ...             ...          ...          ...
# 459  TCGA-4E-A92E  TCGA-4E-A92E             MSS     0.473637     0.046195
# 460  TCGA-2E-A9G8  TCGA-2E-A9G8             MSS     0.404185     0.035739
# 461  TCGA-A5-AB3J  TCGA-A5-AB3J             MSS     0.317685     0.229559
# 462  TCGA-JU-AAVI  TCGA-JU-AAVI             MSS     0.579214     0.021791
# 463  TCGA-DI-A1BU  TCGA-DI-A1BU           MSI-H     0.618343     0.020649
#
#      Nk.cells.all  Macrophages.all  Dendritic.cells.all  Mast.cells.all
# 0        0.094092         0.528625             0.003063        0.006495
# 1        0.083964         0.345620             0.005786        0.017160
# 2        0.072082         0.198086             0.058367        0.019687
# 3        0.029814         0.393554             0.020703        0.020579
# 4        0.147521         0.224501             0.015424        0.031611
# ..            ...              ...                  ...             ...
# 459      0.039144         0.363599             0.000000        0.029639
# 460      0.093531         0.198321             0.010964        0.111427
# 461      0.070916         0.195315             0.000960        0.038476
# 462      0.125063         0.214592             0.004145        0.001104
# 463      0.112676         0.206962             0.000000        0.009519
#
# [464 rows x 36 columns]

# %%
mss = merged[merged.microsatellite == 'MSS'][augmented_cell_types]
msi = merged[merged.microsatellite == 'MSI-H'][augmented_cell_types]

# %%
mss
# Out:
#      B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 0         0.000000        0.080634      0.008700     0.066424
# 1         0.000000        0.053266      0.056248     0.114693
# 2         0.106488        0.019595      0.076636     0.122491
# 3         0.017354        0.000000      0.038209     0.042937
# 4         0.067656        0.012511      0.028619     0.053432
# ..             ...             ...           ...          ...
# 455       0.018168        0.015065      0.277106     0.096912
# 459       0.046195        0.000000      0.030850     0.205641
# 460       0.000000        0.035739      0.111000     0.168203
# 461       0.229559        0.000000      0.143764     0.065165
# 462       0.021791        0.000000      0.054091     0.312219
#
#      T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 0                  0.0                    0.120280
# 1                  0.0                    0.189724
# 2                  0.0                    0.203831
# 3                  0.0                    0.307244
# 4                  0.0                    0.137966
# ..                 ...                         ...
# 455                0.0                    0.042755
# 459                0.0                    0.063863
# 460                0.0                    0.000000
# 461                0.0                    0.178858
# 462                0.0                    0.000000
#
#      T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 0                             0.0                   0.064272
# 1                             0.0                   0.052596
# 2                             0.0                   0.100763
# 3                             0.0                   0.079982
# 4                             0.0                   0.098371
# ..                            ...                        ...
# 455                           0.0                   0.028701
# 459                           0.0                   0.178285
# 460                           0.0                   0.197915
# 461                           0.0                   0.055698
# 462                           0.0                   0.260242
#
#      T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  Mast.cells.resting  \
# 0                      0.027414                  0.0  ...            0.006495
# 1                      0.051296                  0.0  ...            0.017160
# 2                      0.008792                  0.0  ...            0.019687
# 3                      0.000000                  0.0  ...            0.000000
# 4                      0.064538                  0.0  ...            0.031611
# ..                          ...                  ...  ...                 ...
# 455                    0.001256                  0.0  ...            0.190131
# 459                    0.025848                  0.0  ...            0.000000
# 460                    0.038067                  0.0  ...            0.111427
# 461                    0.017964                  0.0  ...            0.038476
# 462                    0.006753                  0.0  ...            0.000000
#
#      Mast.cells.activated  Eosinophils  Neutrophils  T.cells.all  B.cells.all  \
# 0                0.000000     0.000000     0.000000     0.278390     0.080634
# 1                0.000000     0.000000     0.009495     0.408309     0.053266
# 2                0.000000     0.000000     0.000000     0.435877     0.126083
# 3                0.020579     0.018649     0.000000     0.430163     0.017354
# 4                0.000000     0.000000     0.117851     0.354307     0.080167
# ..                    ...          ...          ...          ...          ...
# 455              0.000000     0.000000     0.000000     0.169624     0.033233
# 459              0.029639     0.000000     0.004780     0.473637     0.046195
# 460              0.000000     0.019942     0.000000     0.404185     0.035739
# 461              0.000000     0.000000     0.000000     0.317685     0.229559
# 462              0.001104     0.000000     0.000000     0.579214     0.021791
#
#      Nk.cells.all  Macrophages.all  Dendritic.cells.all  Mast.cells.all
# 0        0.094092         0.528625             0.003063        0.006495
# 1        0.083964         0.345620             0.005786        0.017160
# 2        0.072082         0.198086             0.058367        0.019687
# 3        0.029814         0.393554             0.020703        0.020579
# 4        0.147521         0.224501             0.015424        0.031611
# ..            ...              ...                  ...             ...
# 455      0.101802         0.190892             0.000160        0.190131
# 459      0.039144         0.363599             0.000000        0.029639
# 460      0.093531         0.198321             0.010964        0.111427
# 461      0.070916         0.195315             0.000960        0.038476
# 462      0.125063         0.214592             0.004145        0.001104
#
# [328 rows x 28 columns]

# %% [markdown]
# # Results
#
# ## MSS

# %%
a = 0.05

sanitize = lambda x: 0.0 if x < 0 else 1.0 if x > 1 else x

res_mss = pd.DataFrame(index = cell_types, columns = ['mean', 'mean lower', 'mean upper', 'sd', 'sd lower', 'sd upper'])

n = mss.shape[0];

# Mean
res_mss['mean'] = mss.mean(axis=0)

res_mss['sd'] = mss.std(ddof=1, axis=0)
        
# Mean CI
err = scipy.stats.t.ppf(1 - a / 2, n - 1) * res_mss['sd'] / np.sqrt(n)
res_mss['mean lower'] = (res_mss['mean'] - err).apply(sanitize)
res_mss['mean upper'] = (res_mss['mean'] + err).apply(sanitize)
        
# Standard deviation CI
res_mss['sd lower'] = np.sqrt((n - 1) * res_mss['sd'] ** 2 / scipy.stats.chi2.ppf(1 - a / 2, n - 1))
res_mss['sd upper'] = np.sqrt((n - 1) * res_mss['sd'] ** 2 / scipy.stats.chi2.ppf(a / 2, n - 1))

res_mss
# Out:
#                                   mean  mean lower  mean upper        sd  \
# B.cells.naive                 0.042185    0.035817    0.048553  0.058621
# B.cells.memory                0.031086    0.026197    0.035975  0.045004
# Plasma.cells                  0.061775    0.055269    0.068281  0.059895
# T.cells.CD8                   0.123512    0.115039    0.131985  0.078006
# T.cells.CD4.naive             0.004173    0.002188    0.006158  0.018272
# T.cells.CD4.memory.resting    0.080897    0.072586    0.089209  0.076515
# T.cells.CD4.memory.activated  0.002093    0.001071    0.003116  0.009413
# T.cells.follicular.helper     0.097360    0.090579    0.104141  0.062431
# T.cells.regulatory..Tregs.    0.054648    0.049468    0.059828  0.047689
# T.cells.gamma.delta           0.003530    0.001842    0.005217  0.015535
# NK.cells.resting              0.007351    0.005085    0.009616  0.020859
# NK.cells.activated            0.065329    0.060237    0.070421  0.046880
# Monocytes                     0.020537    0.017792    0.023282  0.025271
# Macrophages.M0                0.104535    0.093194    0.115876  0.104409
# Macrophages.M1                0.031443    0.027796    0.035091  0.033576
# Macrophages.M2                0.179318    0.168181    0.190454  0.102522
# Dendritic.cells.resting       0.005442    0.004076    0.006807  0.012569
# Dendritic.cells.activated     0.024075    0.018999    0.029151  0.046732
# Mast.cells.resting            0.039940    0.033298    0.046581  0.061142
# Mast.cells.activated          0.012587    0.009527    0.015647  0.028170
# Eosinophils                   0.000737    0.000321    0.001153  0.003832
# Neutrophils                   0.007448    0.005064    0.009832  0.021949
#
#                               sd lower  sd upper
# B.cells.naive                 0.054452  0.063487
# B.cells.memory                0.041804  0.048740
# Plasma.cells                  0.055636  0.064867
# T.cells.CD8                   0.072458  0.084480
# T.cells.CD4.naive             0.016973  0.019789
# T.cells.CD4.memory.resting    0.071073  0.082866
# T.cells.CD4.memory.activated  0.008744  0.010194
# T.cells.follicular.helper     0.057991  0.067613
# T.cells.regulatory..Tregs.    0.044297  0.051647
# T.cells.gamma.delta           0.014430  0.016825
# NK.cells.resting              0.019376  0.022591
# NK.cells.activated            0.043546  0.050771
# Monocytes                     0.023473  0.027368
# Macrophages.M0                0.096983  0.113075
# Macrophages.M1                0.031188  0.036363
# Macrophages.M2                0.095231  0.111032
# Dendritic.cells.resting       0.011675  0.013613
# Dendritic.cells.activated     0.043409  0.050611
# Mast.cells.resting            0.056794  0.066217
# Mast.cells.activated          0.026166  0.030508
# Eosinophils                   0.003560  0.004150
# Neutrophils                   0.020388  0.023771

# %% [markdown]
# ## MSI

# %%
a = 0.05

sanitize = lambda x: 0.0 if x < 0 else 1.0 if x > 1 else x

res_msi = pd.DataFrame(index = cell_types, columns = ['mean', 'mean lower', 'mean upper', 'sd', 'sd lower', 'sd upper'])

n = msi.shape[0];

# Mean
res_msi['mean'] = msi.mean(axis=0)

res_msi['sd'] = msi.std(ddof=1, axis=0)
        
# Mean CI
err = scipy.stats.t.ppf(1 - a / 2, n - 1) * res_msi['sd'] / np.sqrt(n)
res_msi['mean lower'] = (res_msi['mean'] - err).apply(sanitize)
res_msi['mean upper'] = (res_msi['mean'] + err).apply(sanitize)
        
# Standard deviation CI
res_msi['sd lower'] = np.sqrt((n - 1) * res_msi['sd'] ** 2 / scipy.stats.chi2.ppf(1 - a / 2, n - 1))
res_msi['sd upper'] = np.sqrt((n - 1) * res_msi['sd'] ** 2 / scipy.stats.chi2.ppf(a / 2, n - 1))

res_msi
# Out:
#                                   mean  mean lower  mean upper        sd  \
# B.cells.naive                 0.040813    0.033391    0.048235  0.043766
# B.cells.memory                0.020004    0.012366    0.027642  0.045039
# Plasma.cells                  0.057544    0.048457    0.066630  0.053581
# T.cells.CD8                   0.180827    0.165011    0.196644  0.093266
# T.cells.CD4.naive             0.001976    0.000020    0.003933  0.011537
# T.cells.CD4.memory.resting    0.054191    0.044688    0.063693  0.056034
# T.cells.CD4.memory.activated  0.004503    0.002289    0.006718  0.013061
# T.cells.follicular.helper     0.133385    0.122402    0.144369  0.064768
# T.cells.regulatory..Tregs.    0.060020    0.051831    0.068210  0.048291
# T.cells.gamma.delta           0.001554    0.000434    0.002673  0.006600
# NK.cells.resting              0.007908    0.004886    0.010930  0.017819
# NK.cells.activated            0.059670    0.051679    0.067660  0.047118
# Monocytes                     0.018518    0.014837    0.022198  0.021703
# Macrophages.M0                0.100828    0.081979    0.119677  0.111149
# Macrophages.M1                0.038222    0.032649    0.043796  0.032865
# Macrophages.M2                0.149160    0.135438    0.162881  0.080913
# Dendritic.cells.resting       0.005794    0.003862    0.007726  0.011392
# Dendritic.cells.activated     0.019133    0.012040    0.026226  0.041825
# Mast.cells.resting            0.013912    0.007586    0.020239  0.037304
# Mast.cells.activated          0.027678    0.020586    0.034770  0.041820
# Eosinophils                   0.000299    0.000000    0.000746  0.002636
# Neutrophils                   0.004060    0.002094    0.006025  0.011590
#
#                               sd lower  sd upper
# B.cells.naive                 0.039110  0.049690
# B.cells.memory                0.040248  0.051136
# Plasma.cells                  0.047881  0.060833
# T.cells.CD8                   0.083344  0.105891
# T.cells.CD4.naive             0.010310  0.013099
# T.cells.CD4.memory.resting    0.050073  0.063619
# T.cells.CD4.memory.activated  0.011671  0.014829
# T.cells.follicular.helper     0.057878  0.073535
# T.cells.regulatory..Tregs.    0.043154  0.054828
# T.cells.gamma.delta           0.005898  0.007493
# NK.cells.resting              0.015923  0.020231
# NK.cells.activated            0.042106  0.053496
# Monocytes                     0.019394  0.024641
# Macrophages.M0                0.099325  0.126194
# Macrophages.M1                0.029369  0.037314
# Macrophages.M2                0.072306  0.091866
# Dendritic.cells.resting       0.010180  0.012935
# Dendritic.cells.activated     0.037376  0.047487
# Mast.cells.resting            0.033335  0.042353
# Mast.cells.activated          0.037371  0.047481
# Eosinophils                   0.002356  0.002993
# Neutrophils                   0.010357  0.013159

# %% [markdown]
# ## Figures

# %%
x_map = {v: i for i, v in enumerate(augmented_cell_types)}

offset_map = {
 'mss': -0.15,
 'msi': 0.15}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

color_map = {'mss': colors[0],
 'msi': colors[1]}

fig = plt.figure(figsize=(10, 3))

ax = fig.add_subplot(1, 1, 1)

n = mss.shape[0];
mean = mss.mean(axis=0)
sd = mss.std(ddof=1, axis=0)
err = scipy.stats.t.ppf(1 - a / 2, n - 1) * sd / np.sqrt(n)

x = [v + offset_map['mss'] for v in x_map.values()]
    
ax.errorbar(x, mean, yerr=sd, fmt='.', color = color_map['mss'], ecolor = 'darkgray', elinewidth=3.0)
ax.errorbar(x, mean, yerr=err, fmt="None", color = color_map['mss'], ecolor = 'black', elinewidth=1.0)

n = msi.shape[0];
mean = msi.mean(axis=0)
sd = msi.std(ddof=1, axis=0)
err = scipy.stats.t.ppf(1 - a / 2, n - 1) * sd / np.sqrt(n)

x = [v + offset_map['msi'] for v in x_map.values()]
    
ax.errorbar(x, mean, yerr=sd, fmt='.', color = color_map['msi'], ecolor = 'darkgray', elinewidth=3.0)
ax.errorbar(x, mean, yerr=err, fmt="None", color = color_map['msi'], ecolor = 'black', elinewidth=1.0)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

current_ylim = ax.get_ylim()
for v in x_map.values():
    if v % 2 == 0:
        ax.fill_between([v - 0.5, v + 0.5], current_ylim[0], current_ylim[1], facecolor='lightgray', alpha=0.2)

ax.set_ylim(current_ylim)
ax.set_xticks(list(x_map.values()))
ax.tick_params(axis='x', which = 'both', labelbottom=None)
ax.set_ylabel('Abundance')
ax.set_xlim(-0.5, len(x_map) - 0.5)
    
# Ticks
ax.tick_params(axis='x', which = 'both', labelbottom=True)
ax.set_xticks(list(x_map.values()))
ax.set_xticklabels(list(x_map.keys()), rotation=30, ha='right')

legend_elements = [mpl.lines.Line2D([0], [0], marker='.', color='w', markerfacecolor=color_map[i], label=i, markersize=15) 
                   for i in color_map]

ax.legend(handles=legend_elements, loc='upper right')

# %%
len(cell_types)
# Out:
# 22
