# %%
import pickle as pkl
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

mpl.rcParams['figure.dpi'] = 300

# %%
from tcga_dicts import *

# %%
def load(cancer_type):
    with open("msi-mss-" + cancer_type + ".pkl", 'rb') as f:
        return pkl.load(f)

ucec = pd.DataFrame(load('ucec'))
coad = pd.DataFrame(load('coad'))
stad = pd.DataFrame(load('stad'))

ucec.index = augmented_cell_types
coad.index = augmented_cell_types
stad.index = augmented_cell_types

# %%
ucec.T
# Out:
#           B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100                 NaN           228.0        2597.0         34.0
# 384                 NaN           211.0        2327.0         30.0
# 1000                NaN           208.0        2269.0         30.0
# baseline            NaN           205.0        2232.0         29.0
#
#           T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100                   672.0                        89.0
# 384                   619.0                        82.0
# 1000                  607.0                        80.0
# baseline              600.0                        79.0
#
#           T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100                              344.0                       49.0
# 384                              295.0                       42.0
# 1000                             284.0                       41.0
# baseline                         277.0                       40.0
#
#           T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100                           1210.0                528.0  ...
# 384                           1046.0                472.0  ...
# 1000                          1010.0                460.0  ...
# baseline                       988.0                453.0  ...
#
#           Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100                     53.0                  80.0       1024.0        392.0
# 384                     49.0                  73.0        782.0        348.0
# 1000                    49.0                  71.0        730.0        339.0
# baseline                48.0                  70.0        697.0        333.0
#
#           T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100              45.0        379.0        1255.0            310.0
# 384              41.0        345.0        1033.0            286.0
# 1000             40.0        338.0         984.0            280.0
# baseline         39.0        333.0         954.0            277.0
#
#           Dendritic.cells.all  Mast.cells.all
# 100                    1282.0           353.0
# 384                    1175.0           322.0
# 1000                   1152.0           315.0
# baseline               1138.0           310.0
#
# [4 rows x 28 columns]

# %%
coad.T
# Out:
#           B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100              4608.0            69.0          74.0        128.0
# 384              4255.0            58.0          66.0        117.0
# 1000             4179.0            56.0          64.0        115.0
# baseline         4131.0            54.0          63.0        113.0
#
#           T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100                   623.0                         NaN
# 384                   583.0                         NaN
# 1000                  575.0                         NaN
# baseline              569.0                         NaN
#
#           T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100                              722.0                      108.0
# 384                              643.0                       91.0
# 1000                             626.0                       87.0
# baseline                         615.0                       85.0
#
#           T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100                            715.0               1090.0  ...
# 384                            603.0                891.0  ...
# 1000                           578.0                848.0  ...
# baseline                       563.0                821.0  ...
#
#           Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100                    457.0                 828.0        503.0         93.0
# 384                    422.0                 769.0        401.0         83.0
# 1000                   414.0                 756.0        379.0         81.0
# baseline               409.0                 748.0        366.0         80.0
#
#           T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100             111.0         75.0          82.0            476.0
# 384             100.0         68.0          63.0            438.0
# 1000             97.0         67.0          59.0            429.0
# baseline         96.0         66.0          56.0            424.0
#
#           Dendritic.cells.all  Mast.cells.all
# 100                     255.0          3995.0
# 384                     211.0          3618.0
# 1000                    201.0          3537.0
# baseline                195.0          3486.0
#
# [4 rows x 28 columns]

# %%
stad.T
# Out:
#           B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100               109.0           115.0         954.0        171.0
# 384                99.0           107.0         870.0        150.0
# 1000               97.0           106.0         851.0        145.0
# baseline           96.0           105.0         840.0        142.0
#
#           T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100                  1181.0                       388.0
# 384                  1080.0                       339.0
# 1000                 1058.0                       328.0
# baseline             1045.0                       322.0
#
#           T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100                               29.0                      242.0
# 384                               26.0                      195.0
# 1000                              25.0                      185.0
# baseline                          25.0                      179.0
#
#           T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100                           1207.0               3316.0  ...
# 384                            972.0               2536.0  ...
# 1000                           920.0               2367.0  ...
# baseline                       889.0               2261.0  ...
#
#           Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100                     39.0                 125.0        512.0          NaN
# 384                     36.0                 115.0        443.0          NaN
# 1000                    35.0                 113.0        428.0          NaN
# baseline                35.0                 112.0        419.0          NaN
#
#           T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100             105.0         71.0           NaN            598.0
# 384              92.0         66.0           NaN            544.0
# 1000             89.0         65.0           NaN            533.0
# baseline         87.0         65.0           NaN            525.0
#
#           Dendritic.cells.all  Mast.cells.all
# 100                     246.0             NaN
# 384                     203.0             NaN
# 1000                    193.0             NaN
# baseline                188.0             NaN
#
# [4 rows x 28 columns]

# %%
augmented_cell_types
# Out:
# ['B.cells.naive',
#  'B.cells.memory',
#  'Plasma.cells',
#  'T.cells.CD8',
#  'T.cells.CD4.naive',
#  'T.cells.CD4.memory.resting',
#  'T.cells.CD4.memory.activated',
#  'T.cells.follicular.helper',
#  'T.cells.regulatory..Tregs.',
#  'T.cells.gamma.delta',
#  'NK.cells.resting',
#  'NK.cells.activated',
#  'Monocytes',
#  'Macrophages.M0',
#  'Macrophages.M1',
#  'Macrophages.M2',
#  'Dendritic.cells.resting',
#  'Dendritic.cells.activated',
#  'Mast.cells.resting',
#  'Mast.cells.activated',
#  'Eosinophils',
#  'Neutrophils',
#  'T.cells.all',
#  'B.cells.all',
#  'Nk.cells.all',
#  'Macrophages.all',
#  'Dendritic.cells.all',
#  'Mast.cells.all']

# %%
markersize = 15

plot_cell_types = [
 'B.cells.naive',
 'B.cells.memory',
 'Plasma.cells',
 'T.cells.CD8',
 'T.cells.CD4.naive',
 'T.cells.CD4.memory.resting',
 'T.cells.CD4.memory.activated',
 'T.cells.follicular.helper',
 'T.cells.regulatory..Tregs.',
 'T.cells.gamma.delta',
 'NK.cells.resting',
 'NK.cells.activated',
 'Monocytes',
 'Eosinophils',
 'Neutrophils',
 'T.cells.all',
 'B.cells.all',
 'Nk.cells.all',
 'Macrophages.all',
 'Dendritic.cells.all',
 'Mast.cells.all'
]

x_map = {v: i for i, v in enumerate(plot_cell_types)}

cell_numbers = [100, 384, 1000, 'baseline']

offset_map = {
 100: -0.3,
 384: -0.1,
 1000: 0.1,
 'baseline': 0.3}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

color_map = {
 100: colors[0],
 384: colors[1],
 1000: colors[2],
 'baseline': colors[3]}

mem = {100: None,
      384: None,
      1000: None,
      'baseline': None}

fig = plt.figure(figsize=(10, 3))

ax = fig.add_subplot(1, 1, 1)

#x = [v + offset_map['baseline'] for v in x_map.values()]
#y = ucec['baseline']
#ax.scatter(x, y, marker='$u$', color = color_map['baseline'], s = 8, alpha = 0.7)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [ucec[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$u$', color=[color_map[cell_number] for cell_number in cell_numbers], s=markersize, alpha=0.7)
    
for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [coad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$c$', color=[color_map[cell_number] for cell_number in cell_numbers], s=markersize, alpha=0.7)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [stad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$s$', color=[color_map[cell_number] for cell_number in cell_numbers], s=markersize, alpha=0.7)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

current_ylim = ax.get_ylim()
for v in x_map.values():
    if v % 2 == 0:
        ax.fill_between([v - 0.5, v + 0.5], current_ylim[0], current_ylim[1], facecolor='lightgray', alpha=0.2)

ax.set_ylim([0, 120])
ax.set_xticks(list(x_map.values()))
ax.tick_params(axis='x', which = 'both', labelbottom=None)
ax.set_ylabel('Estimated sample size for 80% power')
ax.set_xlim(-0.5, len(x_map) + 4)
    
# Ticks
ax.tick_params(axis='x', which = 'both', labelbottom=True)
ax.set_xticks(list(i + 0.5 for i in list(x_map.values())))
ax.set_xticklabels(list(cell_types_cosmetic_dict_short[i] for i in list(x_map.keys())), rotation=30, ha='right')

legend_elements = [mpl.lines.Line2D([0], [0], marker='.', color=color_map[i], linestyle="None", markerfacecolor=color_map[i], label=i) 
                   for i in color_map]

leg1 = ax.legend(handles=legend_elements, loc='lower right', title = 'Number of cells')

legend_elements = [mpl.lines.Line2D([0], [0], marker='$u$', color='k', linestyle="None", label='UCEC')] + \
                  [mpl.lines.Line2D([0], [0], marker='$c$', color='k', linestyle="None", markerfacecolor='k', label='COAD')] + \
                  [mpl.lines.Line2D([0], [0], marker='$s$', color='k', linestyle="None", markerfacecolor='k', label='STAD')]

ax.legend(handles=legend_elements, loc='lower right', title = 'Cancer type')
ax.add_artist(leg1)
ax.yaxis.set_minor_locator(MultipleLocator(10))
ax.yaxis.set_major_locator(MultipleLocator(20))
ax.grid(axis='y', which='both')

# %%
markersize = 15

plot_cell_types = [
 'B.cells.all',
 'B.cells.naive',
 'B.cells.memory',
 'Plasma.cells',
 'T.cells.all',
 'T.cells.CD8',
 'T.cells.CD4.naive',
 'T.cells.CD4.memory.resting',
 'T.cells.CD4.memory.activated',
 'T.cells.follicular.helper',
 'T.cells.regulatory..Tregs.',
 'T.cells.gamma.delta',
 'Nk.cells.all',
 'NK.cells.resting',
 'NK.cells.activated',
 'Monocytes',
 'Eosinophils',
 'Neutrophils',
 'Macrophages.all',
 'Dendritic.cells.all',
 'Mast.cells.all'
]

x_map = {v: i for i, v in enumerate(plot_cell_types)}

cell_numbers = [100, 384, 1000, 'baseline']

offset_map = {
 100: -0.3,
 384: -0.1,
 1000: 0.1,
 'baseline': 0.3}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

color_map = {
 100: colors[0],
 384: colors[1],
 1000: colors[2],
 'baseline': colors[3]}

legend_map ={
 100: 100,
 384: 384,
 1000: 1000,
 'baseline': '+∞'}

mem = {100: None,
      384: None,
      1000: None,
      'baseline': None}

fig = plt.figure(figsize=(10, 3))

ax = fig.add_subplot(1, 1, 1)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [ucec[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$u$', color=['#7f7f7f'], s=markersize, alpha=0.7)
    
for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [coad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$c$', color=['#ff9f0e'], s=markersize, alpha=0.7)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [stad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$s$', color=['#dd5f1e'], s=markersize, alpha=0.7)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

current_ylim = ax.get_ylim()
for v in x_map.values():
    if v % 2 == 0:
        ax.fill_between([v - 0.5, v + 0.5], 0, 1000, facecolor='lightgray', alpha=0.2)

#ax.fill_between([-0.5, 3.5], 0, 1000, facecolor='lightgray', alpha=0.2)
#ax.fill_between([11.5, 13.5], 0, 1000, facecolor='lightgray', alpha=0.2)
        
ax.set_ylim([10, 1000])
ax.set_xticks(list(x_map.values()))
ax.tick_params(axis='x', which = 'both', labelbottom=None)
ax.set_ylabel('Estimated sample size for 80% power')
ax.set_xlim(-0.5, len(x_map) + 4)
    
# Ticks
ax.tick_params(axis='x', which = 'both', labelbottom=True)
ax.set_xticks(list(i + 0.5 for i in list(x_map.values())))
ax.set_xticklabels(list(cell_types_cosmetic_dict_short[i] for i in list(x_map.keys())), rotation=30, ha='right')

#legend_elements = [mpl.lines.Line2D([0], [0], marker='.', color=color_map[i], 
#                                    linestyle="None", markerfacecolor=color_map[i], label=legend_map[i]) for i in color_map]

#leg1 = ax.legend(handles=legend_elements, loc='lower right', title = 'Number of cells')

legend_elements = [mpl.lines.Line2D([0], [0], marker='$u$', color='#7f7f7f', linestyle="None", label='UCEC')] + \
                  [mpl.lines.Line2D([0], [0], marker='$c$', color='#ff9f0e', linestyle="None", markerfacecolor='k', label='COAD')] + \
                  [mpl.lines.Line2D([0], [0], marker='$s$', color='#dd5f1e', linestyle="None", markerfacecolor='k', label='STAD')]


ax.legend(handles=legend_elements, loc='lower right', title = 'Cancer type')

#ax.add_artist(leg1)
ax.set_yscale('log')

ax.grid(axis='y', which='both')

# %%
markersize = 15

plot_cell_types = augmented_cell_types

x_map = {v: i for i, v in enumerate(plot_cell_types)}

cell_numbers = [100, 384, 1000, 'baseline']

offset_map = {
 100: -0.3,
 384: -0.1,
 1000: 0.1,
 'baseline': 0.3}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

color_map = {
 100: colors[0],
 384: colors[1],
 1000: colors[2],
 'baseline': colors[3]}

legend_map ={
 100: 100,
 384: 384,
 1000: 1000,
 'baseline': '+∞'}

mem = {100: None,
      384: None,
      1000: None,
      'baseline': None}

fig = plt.figure(figsize=(10, 3))

ax = fig.add_subplot(1, 1, 1)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [ucec[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$u$', color=['#7f7f7f'], s=markersize, alpha=0.7)
    
for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [coad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$c$', color=['#ff9f0e'], s=markersize, alpha=0.7)

for cell_type, v in x_map.items():
    x = [v + offset_map[cell_number] for cell_number in cell_numbers]
    y = [stad[cell_number][cell_type] for cell_number in cell_numbers]
    ax.plot(x, y, lw=1, c='gray', alpha=0.4)
    ax.scatter(x, y, marker='$s$', color=['#dd5f1e'], s=markersize, alpha=0.7)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

current_ylim = ax.get_ylim()
for v in x_map.values():
    if v % 2 == 0:
        ax.fill_between([v - 0.5, v + 0.5], 0, 1000, facecolor='lightgray', alpha=0.2)

#ax.fill_between([-0.5, 3.5], 0, 1000, facecolor='lightgray', alpha=0.2)
#ax.fill_between([11.5, 13.5], 0, 1000, facecolor='lightgray', alpha=0.2)
        
ax.set_ylim([10, 1000])
ax.set_xticks(list(x_map.values()))
ax.tick_params(axis='x', which = 'both', labelbottom=None)
ax.set_ylabel('Estimated sample size for 80% power')
ax.set_xlim(-0.5, len(x_map) + 4)
    
# Ticks
ax.tick_params(axis='x', which = 'both', labelbottom=True)
ax.set_xticks(list(i + 0.5 for i in list(x_map.values())))
ax.set_xticklabels(list(cell_types_cosmetic_dict_short[i] for i in list(x_map.keys())), rotation=30, ha='right')

#legend_elements = [mpl.lines.Line2D([0], [0], marker='.', color=color_map[i], 
#                                    linestyle="None", markerfacecolor=color_map[i], label=legend_map[i]) for i in color_map]

#leg1 = ax.legend(handles=legend_elements, loc='lower right', title = 'Number of cells')

legend_elements = [mpl.lines.Line2D([0], [0], marker='$u$', color='#7f7f7f', linestyle="None", label='UCEC')] + \
                  [mpl.lines.Line2D([0], [0], marker='$c$', color='#ff9f0e', linestyle="None", markerfacecolor='k', label='COAD')] + \
                  [mpl.lines.Line2D([0], [0], marker='$s$', color='#dd5f1e', linestyle="None", markerfacecolor='k', label='STAD')]

ax.legend(handles=legend_elements, loc='lower right', title = 'Cancer type')

#ax.add_artist(leg1)
ax.set_yscale('log')

ax.grid(axis='y', which='both')

# %%
ucec.columns = [100, 384, 1000, float('inf')]
coad.columns = [100, 384, 1000, float('inf')]
stad.columns = [100, 384, 1000, float('inf')]

# %%
with open("msi-mss.pkl", 'wb') as f:
    pkl.dump({"UCEC": ucec.T, "COAD": coad.T, "STAD": stad.T}, f)

# %%
coad
# Out:
#                               100.0   384.0   1000.0  inf
# B.cells.naive                 4608.0  4255.0  4179.0  4131.0
# B.cells.memory                  69.0    58.0    56.0    54.0
# Plasma.cells                    74.0    66.0    64.0    63.0
# T.cells.CD8                    128.0   117.0   115.0   113.0
# T.cells.CD4.naive              623.0   583.0   575.0   569.0
# T.cells.CD4.memory.resting       NaN     NaN     NaN     NaN
# T.cells.CD4.memory.activated   722.0   643.0   626.0   615.0
# T.cells.follicular.helper      108.0    91.0    87.0    85.0
# T.cells.regulatory..Tregs.     715.0   603.0   578.0   563.0
# T.cells.gamma.delta           1090.0   891.0   848.0   821.0
# NK.cells.resting               868.0   741.0   714.0   697.0
# NK.cells.activated              40.0    35.0    33.0    33.0
# Monocytes                      148.0   121.0   116.0   112.0
# Macrophages.M0                 154.0   146.0   144.0   143.0
# Macrophages.M1                  53.0    44.0    42.0    41.0
# Macrophages.M2                 566.0   507.0   494.0   486.0
# Dendritic.cells.resting        166.0   138.0   132.0   128.0
# Dendritic.cells.activated        NaN     NaN     NaN     NaN
# Mast.cells.resting             457.0   422.0   414.0   409.0
# Mast.cells.activated           828.0   769.0   756.0   748.0
# Eosinophils                    503.0   401.0   379.0   366.0
# Neutrophils                     93.0    83.0    81.0    80.0
# T.cells.all                    111.0   100.0    97.0    96.0
# B.cells.all                     75.0    68.0    67.0    66.0
# Nk.cells.all                    82.0    63.0    59.0    56.0
# Macrophages.all                476.0   438.0   429.0   424.0
# Dendritic.cells.all            255.0   211.0   201.0   195.0
# Mast.cells.all                3995.0  3618.0  3537.0  3486.0
