# %%
import pickle as pkl
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

mpl.rcParams['figure.dpi'] = 300

# %%
from tcga_dicts import *

# %%
def load(filename):
    with open(filename, 'rb') as f:
        return pkl.load(f)

unpaired_primary = load("unpaired.pkl")
unpaired_recurrence = load("unpaired_recurrence.pkl")
paired_primary = load("paired.pkl")
paired_recurrence = load("paired-recurrence.pkl")
msi = load("msi-mss.pkl")

display(unpaired_primary['BLCA'])
display(unpaired_recurrence['LGG'])
display(paired_primary['BLCA'])
display(paired_recurrence['LGG'])
display(msi['COAD'])
# Out:
#         B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100.0              98             443            67          285
# 384.0              91             412            62          261
# 1000.0             90             406            61          256
# inf                89             401            60          253
#
#         T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100.0                  33                          19
# 384.0                  32                          17
# 1000.0                 32                          17
# inf                    31                          17
#
#         T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100.0                            434                        157
# 384.0                            396                        136
# 1000.0                           387                        132
# inf                              382                        129
#
#         T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100.0                          NaN                  239  ...
# 384.0                          NaN                  188  ...
# 1000.0                         NaN                  177  ...
# inf                            NaN                  170  ...
#
#         Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100.0                   24                    51          NaN          NaN
# 384.0                   23                    49          NaN          NaN
# 1000.0                  22                    49          NaN          NaN
# inf                     22                    48        995.0          NaN
#
#         T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100.0           301          915           403               27
# 384.0           275          861           319               26
# 1000.0          270          849           301               25
# inf             266          842           290               25
#
#         Dendritic.cells.all  Mast.cells.all
# 100.0                    22              13
# 384.0                    20              12
# 1000.0                   20              12
# inf                      19              12
#
# [4 rows x 28 columns]
#         B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100.0            3644             158           404          433
# 384.0            3012             141           345          378
# 1000.0           2875             137           333          367
# inf              2789             135           325          359
#
#         T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100.0                 420                        4206
# 384.0                 387                        3785
# 1000.0                380                        3693
# inf                   376                        3636
#
#         T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100.0                           1230                        155
# 384.0                            739                        129
# 1000.0                           633                        124
# inf                              567                        120
#
#         T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100.0                          148                 2457  ...
# 384.0                          100                 1286  ...
# 1000.0                          89                 1032  ...
# inf                             83                  874  ...
#
#         Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100.0                  810                   350          360           62
# 384.0                  772                   333          279           51
# 1000.0                 764                   330          261           48
# inf                    759                   327          250           47
#
#         T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100.0          1345          150            92              127
# 384.0          1193          129            78              118
# 1000.0         1160          125            75              116
# inf            1140          122            73              115
#
#         Dendritic.cells.all  Mast.cells.all
# 100.0                   150            2369
# 384.0                   130            2170
# 1000.0                  126            2127
# inf                     123            2100
#
# [4 rows x 28 columns]
#         B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100.0              85             319            74          164
# 384.0              78             288            68          140
# 1000.0             76             282            67          135
# inf                75             277            66          132
#
#         T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100.0                  33                          13
# 384.0                  32                          11
# 1000.0                 32                          11
# inf                    31                          10
#
#         T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100.0                            156                        150
# 384.0                            117                        129
# 1000.0                           109                        125
# inf                              104                        122
#
#         T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100.0                         1819                  239  ...
# 384.0                         1473                  188  ...
# 1000.0                        1397                  177  ...
# inf                           1351                  170  ...
#
#         Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100.0                   24                    44         1530          NaN
# 384.0                   23                    42         1211          NaN
# 1000.0                  23                    42         1142          NaN
# inf                     23                    41         1098          NaN
#
#         T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100.0           153          767           361               29
# 384.0           128          712           278               28
# 1000.0          122          700           260               27
# inf             119          693           249               27
#
#         Dendritic.cells.all  Mast.cells.all
# 100.0                    21              14
# 384.0                    19              14
# 1000.0                   19              14
# inf                      19              14
#
# [4 rows x 28 columns]
#         B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100.0            4164             146           289          314
# 384.0            3531             129           231          260
# 1000.0           3394             125           219          248
# inf              3308             123           211          241
#
#         T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100.0                 377                        2863
# 384.0                 344                        2441
# 1000.0                337                        2350
# inf                   333                        2293
#
#         T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100.0                           1230                        133
# 384.0                            739                        107
# 1000.0                           633                        102
# inf                              567                         98
#
#         T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100.0                          138                 2457  ...
# 384.0                           90                 1286  ...
# 1000.0                          79                 1032  ...
# inf                             73                  874  ...
#
#         Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100.0                  988                   379          380           60
# 384.0                  950                   362          299           49
# 1000.0                 941                   358          281           46
# inf                    936                   356          271           45
#
#         T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100.0          1082          161            87              111
# 384.0           930          140            73              102
# 1000.0          897          136            70              100
# inf             877          133            69               98
#
#         Dendritic.cells.all  Mast.cells.all
# 100.0                   159            1670
# 384.0                   139            1470
# 1000.0                  135            1427
# inf                     132            1400
#
# [4 rows x 28 columns]
#         B.cells.naive  B.cells.memory  Plasma.cells  T.cells.CD8  \
# 100.0          4608.0            69.0          74.0        128.0
# 384.0          4255.0            58.0          66.0        117.0
# 1000.0         4179.0            56.0          64.0        115.0
# inf            4131.0            54.0          63.0        113.0
#
#         T.cells.CD4.naive  T.cells.CD4.memory.resting  \
# 100.0               623.0                         NaN
# 384.0               583.0                         NaN
# 1000.0              575.0                         NaN
# inf                 569.0                         NaN
#
#         T.cells.CD4.memory.activated  T.cells.follicular.helper  \
# 100.0                          722.0                      108.0
# 384.0                          643.0                       91.0
# 1000.0                         626.0                       87.0
# inf                            615.0                       85.0
#
#         T.cells.regulatory..Tregs.  T.cells.gamma.delta  ...  \
# 100.0                        715.0               1090.0  ...
# 384.0                        603.0                891.0  ...
# 1000.0                       578.0                848.0  ...
# inf                          563.0                821.0  ...
#
#         Mast.cells.resting  Mast.cells.activated  Eosinophils  Neutrophils  \
# 100.0                457.0                 828.0        503.0         93.0
# 384.0                422.0                 769.0        401.0         83.0
# 1000.0               414.0                 756.0        379.0         81.0
# inf                  409.0                 748.0        366.0         80.0
#
#         T.cells.all  B.cells.all  Nk.cells.all  Macrophages.all  \
# 100.0         111.0         75.0          82.0            476.0
# 384.0         100.0         68.0          63.0            438.0
# 1000.0         97.0         67.0          59.0            429.0
# inf            96.0         66.0          56.0            424.0
#
#         Dendritic.cells.all  Mast.cells.all
# 100.0                 255.0          3995.0
# 384.0                 211.0          3618.0
# 1000.0                201.0          3537.0
# inf                   195.0          3486.0
#
# [4 rows x 28 columns]

# %%
unpaired['GBM']
# Out:
#        B.cells.naive B.cells.memory Plasma.cells T.cells.CD8  \
# 100.0            NaN            NaN          NaN         NaN
# 384.0            NaN            NaN          NaN         NaN
# 1000.0           NaN            NaN          NaN         NaN
# inf              NaN            NaN          NaN         NaN
#
#        T.cells.CD4.naive T.cells.CD4.memory.resting  \
# 100.0                NaN                        NaN
# 384.0                NaN                        NaN
# 1000.0               NaN                        NaN
# inf                  NaN                        NaN
#
#        T.cells.CD4.memory.activated T.cells.follicular.helper  \
# 100.0                           NaN                       NaN
# 384.0                           NaN                       NaN
# 1000.0                          NaN                       NaN
# inf                             NaN                       NaN
#
#        T.cells.regulatory..Tregs. T.cells.gamma.delta  ... Mast.cells.resting  \
# 100.0                         NaN                 NaN  ...                NaN
# 384.0                         NaN                 NaN  ...                NaN
# 1000.0                        NaN                 NaN  ...                NaN
# inf                           NaN                 NaN  ...                NaN
#
#        Mast.cells.activated Eosinophils Neutrophils T.cells.all B.cells.all  \
# 100.0                   NaN         NaN         NaN         NaN         NaN
# 384.0                   NaN         NaN         NaN         NaN         NaN
# 1000.0                  NaN         NaN         NaN         NaN         NaN
# inf                     NaN         NaN         NaN         NaN         NaN
#
#        Nk.cells.all Macrophages.all Dendritic.cells.all Mast.cells.all
# 100.0           NaN             NaN                 NaN            NaN
# 384.0           NaN             NaN                 NaN            NaN
# 1000.0          NaN             NaN                 NaN            NaN
# inf             NaN             NaN                 NaN            NaN
#
# [4 rows x 28 columns]

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
    'B.cells.all',
    'T.cells.all',
    'Nk.cells.all',
    'Monocytes',
    'Eosinophils',
    'Neutrophils',
    'Macrophages.all',
    'Dendritic.cells.all',
    'Mast.cells.all'
]

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 100
center_key2 = 384
center_key = 1000
lower_key = float('inf')


## Pair vs unpaired by colors
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_map = {'unpaired': colors[0], 'paired': colors[1]}

fig = plt.figure(figsize=(12, 8))

axes = []

elinewidth = 1
ecolor = 'k'

for cell_type in cell_types:
    if len(axes) == 0:
        axes.append(fig.add_subplot(1, n_cell_types, 1))
    else:
        axes.append(fig.add_subplot(1, n_cell_types, len(axes) + 1, sharey = axes[0]))
        
    ax = axes[-1]
    
    for v in range(n_cancer_types):
        if v % 2 == 0:
            ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.2)
    
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):
        y = i - 0.2
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 0.2
        x_l = paired_primary[cancer_type][cell_type][lower_key]
        x = paired_primary[cancer_type][cell_type][center_key]
        x_u = paired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for j, cancer_type in enumerate(recurrence_cancer_types):
        y = i + 1 + j - 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 1 + j + 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for k, cancer_type in enumerate(msi_mss_cancer_types):
        y = i + j + 2 + k - 0.2
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = msi[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
    
    ax.set_xlim([0, 200])
    ax.set_xticks([20, 40, 60, 80, 120, 140, 160, 180], True)
    #ax.set_xscale('log')
    ax.grid(axis='x', which='both', alpha=0.3)

    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    ax.tick_params(axis='y', which = 'both', labelleft=None)
    ax.tick_params(axis='y', which='minor', length=0)
    ax.set_xticklabels([int(i) for i in ax.get_xticks()], rotation = 90, ha="center")
    ax.set_xlabel(cell_types_cosmetic_dict_short[cell_type])    
    
        
ax = axes[0]
ax.set_yticks(list(i for i in range(n_cancer_types)), True)
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels("", va = 'center')
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'center', minor = True)
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.tick_params(axis='y', which='minor', length=0)
ax.set_ylim([-0.5, i + j + k + 2.5])
ax.invert_yaxis()


par = ax.twinx()
#par.axis["left"] = new_axisline(loc="left", axes=par, offset=(-25, 0))

par.spines["left"].set_position(("axes", -0.6))
par.yaxis.tick_left()
par.tick_params(direction='in')
par.tick_params(which='minor', length=0)
par.set_yticklabels('')
par.set_yticklabels(['Normal \nvs     \nprimary ', 'Primary \nvs     \nrecurrent', 'MSI-H  \nvs     \nMSS   '], 
                    minor=True)

par.set_ylim([-0.5, i + j + k + 2.5])
par.set_ylim([-0.5, i + j + k + 2.5])
par.set_yticks([-0.5, i + 0.5, i + j + 1.5, i + j + k + 2.5])
par.set_yticks([i / 2, (2 * i + j + 2) / 2, (2 * i + 2 * j + k + 4) / 2], True)
par.invert_yaxis()

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
par.spines['right'].set_visible(False)
par.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='s',
                                    ms=5,
                                    color=color_map[i], 
                                    linestyle="None", 
                                    label=i)
                                    for i in color_map]
axes[-1].legend(handles=legend_elements, loc='lower right', title = 'Test type', prop={'size': 7.5})

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = ['B.cells.naive',
 'B.cells.memory',
 'Plasma.cells',
 'T.cells.CD8',
 'T.cells.CD4.naive',
 'T.cells.CD4.memory.resting',
 'T.cells.CD4.memory.activated',
 'T.cells.follicular.helper',
 'T.cells.regulatory..Tregs.',
 'T.cells.gamma.delta'
 ]

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 100
center_key2 = 384
center_key = 1000
lower_key = float('inf')


## Pair vs unpaired by colors
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_map = {'unpaired': colors[0], 'paired': colors[1]}

fig = plt.figure(figsize=(12, 8))

axes = []

elinewidth = 1
ecolor = 'k'

for cell_type in cell_types:
    if len(axes) == 0:
        axes.append(fig.add_subplot(1, n_cell_types, 1))
    else:
        axes.append(fig.add_subplot(1, n_cell_types, len(axes) + 1, sharey = axes[0]))
        
    ax = axes[-1]
    
    for v in range(n_cancer_types):
        if v % 2 == 0:
            ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.2)
    
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):
        y = i - 0.2
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 0.2
        x_l = paired_primary[cancer_type][cell_type][lower_key]
        x = paired_primary[cancer_type][cell_type][center_key]
        x_u = paired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for j, cancer_type in enumerate(recurrence_cancer_types):
        y = i + 1 + j - 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 1 + j + 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for k, cancer_type in enumerate(msi_mss_cancer_types):
        y = i + j + 2 + k - 0.2
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = msi[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
    
    ax.set_xlim([0, 200])
    ax.set_xticks([0, 100, 200])
    ax.set_xticks([20, 40, 60, 80, 120, 140, 160, 180], True)
    #ax.set_xscale('log')
    ax.grid(axis='x', which='both', alpha=0.3)

    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    ax.tick_params(axis='y', which = 'both', labelleft=None)
    ax.tick_params(axis='y', which='minor', length=0)
    ax.set_xticklabels([int(i) for i in ax.get_xticks()], rotation = 90, ha="center")
    ax.set_xlabel(('\n' if len(axes) % 2 == 0 and len(axes) > 4 else '') + cell_types_cosmetic_dict_short[cell_type])    
    
        
ax = axes[0]
ax.set_yticks(list(i for i in range(n_cancer_types)), True)
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels("", va = 'center')
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'center', minor = True)
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.tick_params(axis='y', which='minor', length=0)
ax.set_ylim([-0.5, i + j + k + 2.5])
ax.invert_yaxis()


par = ax.twinx()
#par.axis["left"] = new_axisline(loc="left", axes=par, offset=(-25, 0))

par.spines["left"].set_position(("axes", -0.6))
par.yaxis.tick_left()
par.tick_params(direction='in')
par.tick_params(which='minor', length=0)
par.set_yticklabels('')
par.set_yticklabels(['Normal \nvs     \nprimary ', 'Primary \nvs     \nrecurrent', 'MSI-H  \nvs     \nMSS   '], 
                    minor=True)

par.set_ylim([-0.5, i + j + k + 2.5])
par.set_ylim([-0.5, i + j + k + 2.5])
par.set_yticks([-0.5, i + 0.5, i + j + 1.5, i + j + k + 2.5])
par.set_yticks([i / 2, (2 * i + j + 2) / 2, (2 * i + 2 * j + k + 4) / 2], True)
par.invert_yaxis()

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
par.spines['right'].set_visible(False)
par.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='s',
                                    ms=5,
                                    color=color_map[i], 
                                    linestyle="None", 
                                    label=i)
                                    for i in color_map]
#axes[-1].legend(handles=legend_elements, loc='lower right', title = 'Test type', prop={'size': 7.5})

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
 'NK.cells.resting',
 'NK.cells.activated',
 'Macrophages.M0',
 'Macrophages.M1',
 'Macrophages.M2',
 'Dendritic.cells.resting',
 'Dendritic.cells.activated',
 'Mast.cells.resting',
 'Mast.cells.activated',
 ]

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 100
center_key2 = 384
center_key = 1000
lower_key = float('inf')


## Pair vs unpaired by colors
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_map = {'unpaired': colors[0], 'paired': colors[1]}

fig = plt.figure(figsize=(12, 8))

axes = []

elinewidth = 1
ecolor = 'k'

for cell_type in cell_types:
    if len(axes) == 0:
        axes.append(fig.add_subplot(1, n_cell_types, 1))
    else:
        axes.append(fig.add_subplot(1, n_cell_types, len(axes) + 1, sharey = axes[0]))
        
    ax = axes[-1]
    
    for v in range(n_cancer_types):
        if v % 2 == 0:
            ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.2)
    
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):
        y = i - 0.2
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 0.2
        x_l = paired_primary[cancer_type][cell_type][lower_key]
        x = paired_primary[cancer_type][cell_type][center_key]
        x_u = paired_primary[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_primary[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for j, cancer_type in enumerate(recurrence_cancer_types):
        y = i + 1 + j - 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = unpaired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 1 + j + 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = paired_recurrence[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for k, cancer_type in enumerate(msi_mss_cancer_types):
        y = i + j + 2 + k - 0.2
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        if x < 200:
            ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                        color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
            x = msi[cancer_type][cell_type][center_key2]
            ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
    
    ax.set_xlim([0, 200])
    ax.set_xticks([0, 100, 200])
    ax.set_xticks([20, 40, 60, 80, 120, 140, 160, 180], True)
    #ax.set_xscale('log')
    ax.grid(axis='x', which='both', alpha=0.3)

    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    ax.tick_params(axis='y', which = 'both', labelleft=None)
    ax.tick_params(axis='y', which='minor', length=0)
    ax.set_xticklabels([int(i) for i in ax.get_xticks()], rotation = 90, ha="center")
    ax.set_xlabel(('\n' if len(axes) % 2 == 0 else '') + cell_types_cosmetic_dict_short[cell_type])    
    
        
ax = axes[0]
ax.set_yticks(list(i for i in range(n_cancer_types)), True)
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels("", va = 'center')
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'center', minor = True)
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.tick_params(axis='y', which='minor', length=0)
ax.set_ylim([-0.5, i + j + k + 2.5])
ax.invert_yaxis()


par = ax.twinx()
#par.axis["left"] = new_axisline(loc="left", axes=par, offset=(-25, 0))

par.spines["left"].set_position(("axes", -0.6))
par.yaxis.tick_left()
par.tick_params(direction='in')
par.tick_params(which='minor', length=0)
par.set_yticklabels('')
par.set_yticklabels(['Normal \nvs     \nprimary ', 'Primary \nvs     \nrecurrent', 'MSI-H  \nvs     \nMSS   '], 
                    minor=True)

par.set_ylim([-0.5, i + j + k + 2.5])
par.set_ylim([-0.5, i + j + k + 2.5])
par.set_yticks([-0.5, i + 0.5, i + j + 1.5, i + j + k + 2.5])
par.set_yticks([i / 2, (2 * i + j + 2) / 2, (2 * i + 2 * j + k + 4) / 2], True)
par.invert_yaxis()

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
par.spines['right'].set_visible(False)
par.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='s',
                                    ms=5,
                                    color=color_map[i], 
                                    linestyle="None", 
                                    label=i)
                                    for i in color_map]
#axes[-1].legend(handles=legend_elements, loc='lower right', title = 'Test type', prop={'size': 7.5})

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
    'B.cells.all',
    'T.cells.all',
    'Nk.cells.all',
    'Monocytes',
    'Eosinophils',
    'Neutrophils',
    'Macrophages.all',
    'Dendritic.cells.all',
    'Mast.cells.all'
]

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 100
center_key2 = 384
center_key = 1000
lower_key = float('inf')


## Pair vs unpaired by colors
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_map = {'unpaired': colors[0], 'paired': colors[1]}

fig = plt.figure(figsize=(12.8, 8))

axes = []

elinewidth = 1
ecolor = 'k'

for cell_type in cell_types:
    if len(axes) == 0:
        axes.append(fig.add_subplot(1, n_cell_types, 1))
    else:
        axes.append(fig.add_subplot(1, n_cell_types, len(axes) + 1, sharey = axes[0]))
        
    ax = axes[-1]
    
    for v in range(n_cancer_types):
        if v % 2 == 0:
            ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.2)
    
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):
        y = i - 0.2
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                    color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
        x = unpaired_primary[cancer_type][cell_type][center_key2]
        ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 0.2
        x_l = paired_primary[cancer_type][cell_type][lower_key]
        x = paired_primary[cancer_type][cell_type][center_key]
        x_u = paired_primary[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                    color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
        x = paired_primary[cancer_type][cell_type][center_key2]
        ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for j, cancer_type in enumerate(recurrence_cancer_types):
        y = i + 1 + j - 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                    color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
        x = unpaired_recurrence[cancer_type][cell_type][center_key2]
        ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
        
        y = i + 1 + j + 0.2
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                    color=color_map['paired'], ecolor=color_map['paired'], elinewidth=elinewidth, fmt='|', ms=6)
        x = paired_recurrence[cancer_type][cell_type][center_key2]
        ax.errorbar(x, y, color=color_map['paired'], fmt='|', ms=6)
        
    for k, cancer_type in enumerate(msi_mss_cancer_types):
        y = i + j + 2 + k - 0.2
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], 
                    color=color_map['unpaired'], ecolor=color_map['unpaired'], elinewidth=elinewidth, fmt='|', ms=6)
        x = msi[cancer_type][cell_type][center_key2]
        ax.errorbar(x, y, color=color_map['unpaired'], fmt='|', ms=6)
    
    ax.set_xlim([5, 200])
    ax.set_xscale('log')
    ax.set_xticks([10, 100])
    ax.set_xticks([5, 20, 40, 60, 80], True)
    ax.grid(axis='x', which='both', alpha = 0.3)

    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

    ax.tick_params(axis='y', which = 'both', labelleft=None)
    # ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, ha="center")
    ax.set_xlabel(cell_types_cosmetic_dict_short[cell_type])    
    
    ax.set_ylim([-0.5, i + j + k + 2.5])
        
ax = axes[0]
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'bottom')
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.invert_yaxis()

par = ax.twinx()
#par.axis["left"] = new_axisline(loc="left", axes=par, offset=(-25, 0))
par.set_ylim([-0.5, i + j + k + 2.5])
par.set_yticks([-0.5, i + 0.5, i + j + 1.5, i + j + k + 2.5])
par.set_yticks([i / 2, (2 * i + j + 2) / 2, (2 * i + 2 * j + k + 4) / 2], True)
par.invert_yaxis()

par.spines["left"].set_position(("axes", -0.6))
par.yaxis.tick_left()
par.tick_params(direction='in')
par.tick_params(which='minor', length = 0)
par.set_yticklabels('')
par.set_yticklabels(['Normal \nvs     \nprimary ', 'Primary \nvs     \nrecurrent', 'MSI-H \nvs     \nMSS   '], 
                    minor=True)
par.set_ylim([-0.5, i + j + k + 2.5])
par.invert_yaxis()
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
par.spines['right'].set_visible(False)
par.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='s',
                                    ms=5,
                                    color=color_map[i], 
                                    linestyle="None", 
                                    label=i)
                                    for i in color_map]
axes[-1].legend(handles=legend_elements, loc='lower right', title = 'Test type', prop={'size': 7.5})

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
    'B.cells.all',
    'T.cells.all',
    'Nk.cells.all',
    'Monocytes',
    'Eosinophils',
    'Neutrophils',
    'Macrophages.all',
    'Dendritic.cells.all',
    'Mast.cells.all'
]

cell_type_markers = {
    'B.cells.all': "B",
    'T.cells.all': "T",
    'Nk.cells.all': "K",
    'Monocytes': "1",
    'Eosinophils': "E",
    'Neutrophils': "N",
    'Macrophages.all': "P",
    'Dendritic.cells.all': "D",
    'Mast.cells.all': "M"
}

cell_type_offsets = {
    'B.cells.all': -0.4,
    'T.cells.all': -0.3,
    'Nk.cells.all': -0.2,
    'Monocytes': -0.1,
    'Eosinophils': 0.00,
    'Neutrophils': 0.1,
    'Macrophages.all': 0.2,
    'Dendritic.cells.all': 0.3,
    'Mast.cells.all': 0.4,
}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

cell_type_colors = {k: colors[i] for i, k in enumerate(cell_types)}

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 384
center_key = 1000
lower_key = float('inf')


fig = plt.figure(figsize=(6.4, 5))

axes = []
axes.append(fig.add_subplot(1, 1, 1))
ax = axes[-1]

for v in range(n_cancer_types):
    if v % 2 == 0:
        ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.1)

for cell_type in cell_types:
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + cell_type_offsets[cell_type]
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor=cell_type_colors[cell_type], elinewidth=1, alpha=0.3)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.8)
        
    # recurrent
    for j, cancer_type in enumerate(recurrence_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + 1 + j + cell_type_offsets[cell_type]
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor=cell_type_colors[cell_type], elinewidth=1, alpha=0.3)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.8)
        
    # msi
    for k, cancer_type in enumerate(msi_mss_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + 1 + j + 1 + k + cell_type_offsets[cell_type]
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor=cell_type_colors[cell_type], elinewidth=1, alpha=0.3)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.8)

ax.set_xlabel('Estimated sample size for 80% power')
        
ax.set_xlim([0, 200])
#ax.set_xscale('log')
ax.grid(axis='x', which='both')
        
ax = axes[0]
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'bottom')
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.set_ylim([-0.5, i + j + k + 2.5])
ax.invert_yaxis()

par = ax.twinx()
#par.axis["left"] = new_axisline(loc="left", axes=par, offset=(-25, 0))
par.set_ylim([-0.5, i + j + k + 2.5])
par.set_yticks([-0.5, i + 0.5, i + j + 1.5, i + j + k + 2.5])
par.set_yticks([i / 2, (2 * i + j + 2) / 2, (2 * i + 2 * j + k + 4) / 2], True)
par.invert_yaxis()

par.spines["left"].set_position(("axes", -0.12))
par.yaxis.tick_left()
par.tick_params(direction='in')
par.tick_params(which='minor', length = 0)
par.set_yticklabels('')
par.set_yticklabels(['Normal \nvs     \nprimary ', 'Primary \nvs     \nrecurrent', 'MSI-H \nvs     \nMSS   '], 
                    minor=True, fontdict={'fontsize': 7})

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
par.spines['right'].set_visible(False)
par.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='$' + cell_type_markers[i] + '$',
                                    ms=5,
                                    color=cell_type_colors[i], 
                                    linestyle="None", 
                                    label=cell_types_cosmetic_dict_short[i])
                                    for i in cell_type_markers]
ax.legend(handles=legend_elements, loc='upper right', title = 'Cell type', prop={'size': 7})

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
    'B.cells.all',
    'T.cells.all',
    'Nk.cells.all',
    'Monocytes',
    'Eosinophils',
    'Neutrophils',
    'Macrophages.all',
    'Dendritic.cells.all',
    'Mast.cells.all'
]

cell_type_markers = {
    'B.cells.all': "B",
    'T.cells.all': "T",
    'Nk.cells.all': "K",
    'Monocytes': "1",
    'Eosinophils': "E",
    'Neutrophils': "N",
    'Macrophages.all': "P",
    'Dendritic.cells.all': "D",
    'Mast.cells.all': "M"
}

cell_type_offsets = {
    'B.cells.all': -0.4,
    'T.cells.all': -0.3,
    'Nk.cells.all': -0.2,
    'Monocytes': -0.1,
    'Eosinophils': 0.00,
    'Neutrophils': 0.1,
    'Macrophages.all': 0.2,
    'Dendritic.cells.all': 0.3,
    'Mast.cells.all': 0.4,
}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

cell_type_colors = {k: colors[i] for i, k in enumerate(cell_types)}

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 384
center_key = 1000
lower_key = float('inf')


fig = plt.figure(figsize=(6.4, 5))

axes = []
axes.append(fig.add_subplot(1, 1, 1))
ax = axes[-1]

for v in range(n_cancer_types):
    if v % 2 == 0:
        ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.1)

for cell_type in cell_types:
    # primary
    for i, cancer_type in enumerate(primary_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + cell_type_offsets[cell_type]
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor='gray', elinewidth=1, alpha=0.5)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.9)
        
    # recurrent
    for j, cancer_type in enumerate(recurrence_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + 1 + j + cell_type_offsets[cell_type]
        x_l = unpaired_recurrence[cancer_type][cell_type][lower_key]
        x = unpaired_recurrence[cancer_type][cell_type][center_key]
        x_u = unpaired_recurrence[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor='gray', elinewidth=1, alpha=0.5)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.9)
        
    # msi
    for k, cancer_type in enumerate(msi_mss_cancer_types):        
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + 1 + j + 1 + k + cell_type_offsets[cell_type]
        x_l = msi[cancer_type][cell_type][lower_key]
        x = msi[cancer_type][cell_type][center_key]
        x_u = msi[cancer_type][cell_type][upper_key]
        
        if (x > 200): continue
        
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor='gray', elinewidth=1, alpha=0.5)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='$' + cell_type_markers[cell_type] + '$', s=15, alpha=0.9)
        
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.set_xlabel('Estimated sample size for 80% power')
        
ax.set_xlim([1, 1000])
ax.set_xscale('log')
ax.grid(axis='x', which='both')
        
ax = axes[0]
ax.set_yticks(list(i + 0.5 for i in range(n_cancer_types)))
ax.set_yticklabels(primary_cancer_types + recurrence_cancer_types + msi_mss_cancer_types, va = 'bottom')
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.invert_yaxis()

legend_elements = [mpl.lines.Line2D([0], [0], 
                                    marker='$' + cell_type_markers[i] + '$',
                                    ms=5,
                                    color=cell_type_colors[i], 
                                    linestyle="None", 
                                    label=cell_types_cosmetic_dict_short[i])
                                    for i in cell_type_markers]

ax.legend(handles=legend_elements, loc='upper right', title = 'Cell type', prop={'size': 7})

# %%
msi['COAD']['B.cells.all'][1000]
# Out:
# 67.0

# %%
msi_mss_cancer_types
# Out:
# ['UCEC', 'COAD', 'STAD']

# %%
markersize = 15

## All cancer types share one figure
primary_cancer_types = [
    'BLCA',
    'BRCA',
    'CHOL',
    'COAD',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LIHC',
    'LUAD',
    'LUSC',
    'PRAD',
    'READ',
    'STAD',
    'THCA',
    'UCEC'
]

recurrence_cancer_types = [
    'GBM',
    'LGG'
]

msi_mss_cancer_types = [
    'UCEC',
    'COAD',
    'STAD'
]

n_cancer_types = len(primary_cancer_types) + len(recurrence_cancer_types) + len(msi_mss_cancer_types)

## Each cell type has a figure
cell_types = [
    'B.cells.all',
    'T.cells.all',
    'Nk.cells.all',
    'Monocytes',
    'Eosinophils',
    'Neutrophils',
    'Macrophages.all',
    'Dendritic.cells.all',
    'Mast.cells.all'
]

cell_type_offsets = {
    'B.cells.all': -0.4,
    'T.cells.all': -0.3,
    'Nk.cells.all': -0.2,
    'Monocytes': -0.1,
    'Eosinophils': 0.00,
    'Neutrophils': 0.1,
    'Macrophages.all': 0.2,
    'Dendritic.cells.all': 0.3,
    'Mast.cells.all': 0.4,
}

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

cell_type_colors = {k: colors[i] for i, k in enumerate(cell_types)}

n_cell_types = len(cell_types)

## Number is represented by error bar
upper_key = 384
center_key = 1000
lower_key = float('inf')




fig = plt.figure(figsize=(6.4, 6))

axes = []
axes.append(fig.add_subplot(1, 1, 1))
ax = axes[-1]

for v in range(n_cancer_types):
    if v % 2 == 0:
        ax.fill_between([0, 1000], v - 0.5, v + 0.5, facecolor='lightgray', alpha=0.05)

for cell_type in cell_types:
    for i, cancer_type in enumerate(primary_cancer_types):        
                
        ax.tick_params(axis='y', which = 'both', labelleft=None)
        y = i + cell_type_offsets[cell_type]
        x_l = unpaired_primary[cancer_type][cell_type][lower_key]
        x = unpaired_primary[cancer_type][cell_type][center_key]
        x_u = unpaired_primary[cancer_type][cell_type][upper_key]
        ax.errorbar(x, y, xerr=[[x - x_l], [x_u - x]], ecolor='gray', elinewidth=2, alpha=0.5)
        ax.scatter(x, y, color=cell_type_colors[cell_type], marker='.', s=12, alpha=0.8)
        
        # Hide the right and top spines
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)

        # Only show ticks on the left and bottom spines
        ax.yaxis.set_ticks_position('left')
        ax.xaxis.set_ticks_position('bottom')
        
        ax.set_xlabel(cell_types_cosmetic_dict_short[cell_type])
        
ax.set_xlim([4, 1000])
ax.set_xscale('log')
ax.grid(axis='x', which='both')

ax = axes[0]
ax.set_yticks(list(i + 0.5 for i in range(len(primary_cancer_types))))
ax.set_yticklabels(primary_cancer_types, va = 'bottom')
ax.tick_params(axis='y', which = 'both', labelleft=True)
ax.invert_yaxis()

# %%
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

current_ylim = ax.get_ylim()
for v in x_map.values():
    if v % 2 == 0:
        ax.fill_between([v - 0.5, v + 0.5], 0, 1000, facecolor='lightgray', alpha=0.2)

#ax.fill_between([-0.5, 3.5], 0, 1000, facecolor='lightgray', alpha=0.2)
#ax.fill_between([11.5, 13.5], 0, 1000, facecolor='lightgray', alpha=0.2)
        
ax.set_ylim([10, 1000])
ax.set_xticks(list(x_map.values()))
ax.tick_params(axis='x', which = 'both', labelbottom=None)
ax.set_ylabel('Estimated sample size for 80% power')
ax.set_xlim(-0.5, len(x_map) + 4)
    
# Ticks
ax.tick_params(axis='x', which = 'both', labelbottom=True)
ax.set_xticks(list(i + 0.5 for i in range(len(primary_cancer_types))))
ax.set_xticklabels(primary_cancer_types, rotation=30, ha='right')

#legend_elements = [mpl.lines.Line2D([0], [0], marker='.', color=color_map[i], 
#                                    linestyle="None", markerfacecolor=color_map[i], label=legend_map[i]) for i in color_map]

#leg1 = ax.legend(handles=legend_elements, loc='lower right', title = 'Number of cells')

legend_elements = [mpl.lines.Line2D([0], [0], marker='$u$', color='#7f7f7f', linestyle="None", label='UCEC')] + \
                  [mpl.lines.Line2D([0], [0], marker='$c$', color='#ff9f0e', linestyle="None", markerfacecolor='k', label='COAD')] + \
                  [mpl.lines.Line2D([0], [0], marker='$s$', color='#dd5f1e', linestyle="None", markerfacecolor='k', label='STAD')]

ax.legend(handles=legend_elements, loc='lower right', title = 'Cancer type')

#ax.add_artist(leg1)
ax.set_yscale('log')

ax.grid(axis='y', which='both')
